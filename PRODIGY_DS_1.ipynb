# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhan5559/PRODIGY_DS_2/blob/main/PRODIGY_DS_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Step 2: Load the dataset
file_path = '/content/API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv'  # update if different
df = pd.read_csv(file_path, skiprows=4)

# Step 3: Select top 10 countries by population in 2023
df_2023 = df[['Country Name', '2023']].dropna()
top_countries = df_2023.sort_values(by='2023', ascending=False).head(10)

# Step 4: Plot the bar chart
plt.figure(figsize=(12, 6))
plt.bar(top_countries['Country Name'], top_countries['2023'], color='lightgreen', edgecolor='black')
plt.title('Top 10 Most Populous Countries in 2023')
plt.xlabel('Country')
plt.ylabel('Population')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
